# %% [markdown]
# ## Canine GWAS Reference Data

# %%
import os
import pandas as pd
import numpy as np
import os.path as osp
# %run {os.environ['NB_DIR']}/nb.py
# %run paths.py

# %%
pd.options.display.max_rows = 1000
df = pd.read_excel(osp.join(ORGANISM_CANINE_REF_DIR, '1-s2.0-S2211124717304564-mmc2.xlsx'), sheet_name=0)
df = df.rename(columns={'Abrev.': 'Abrev'})
df[['Breed', 'Abrev', 'Clade']].fillna('<NA>').astype(str).sort_values('Abrev').drop_duplicates()
# Out:
#                                                  Breed Abrev  \
# 165                                       TOTAL BREEDS   164
# 166                                               <NA>   167
# 174  COO = dogs collected in the country from which...  <NA>
# 172  2 - Hayward JJ, et al. (2016) Complex disease ...  <NA>
# 171  1 - Vaysse A, et al. (2011) Identification of ...  <NA>
# 170  * - breeds included in the clade with <50% boo...  <NA>
# 169                                               <NA>  <NA>
# 164                                   TOTAL BREED DOGS  <NA>
# 173  3 - Mizzou Comparative Canine Resequencing: Bi...  <NA>
# 0                              American Cocker Spaniel  ACKR
# 1                                  American Eskimo Dog  AESK
# 2                                         Afghan Hound  AFGH
# 3                            American Hairless Terrier  AHRT
# 4                                     Airedale Terrier  AIRT
# ...
